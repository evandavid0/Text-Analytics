# %%
from selenium import webdriver
import re
import csv
driver = webdriver.Chrome('/Users/Andrew/Desktop/MSBA/chromedriver')
Uauthor=[]
Udate=[]
Uscore=[]
Ucomment=[]
Ugame=[]
Cauthor =[]
Cdate=[]
Cscore=[]
Ccomment=[]
Cgame=[]

# %%
# OVERWATCH(PC)
driver.get("https://www.metacritic.com/game/pc/overwatch/critic-reviews")
critics = driver.find_elements_by_class_name('review_section')

for a in critics:
        Full = a.text.split("\n")
        if len(Full) > 3:
            Cauthor.append(Full[0])
            Cdate.append(Full[1])
            Cscore.append(Full[2])
            Ccomment.append(Full[3])
            Cgame.append("Overwatch")
        else:
            continue
i = 1
num_pages = 11
for i in range(1,num_pages+1):
    driver.get("https://www.metacritic.com/game/pc/overwatch/user-reviews?page=" + str(i-1))
    name_date_score = driver.find_elements_by_class_name('review_section')
    for a in name_date_score[0:-6]:
        Full = a.text.split("\n")
        if len(Full) > 2:
            Uauthor.append(Full[0])
            Udate.append(Full[1])
            Uscore.append(Full[2])
            Ucomment.append(Full[3])
            Ugame.append("Overwatch")
        else:
            continue

# %%
# Halo MCC (PC)
driver.get("https://www.metacritic.com/game/xbox-one/halo-the-master-chief-collection/critic-reviews")
critics = driver.find_elements_by_class_name('review_section')

for a in critics:
        Full = a.text.split("\n")
        if len(Full) > 3:
            Cauthor.append(Full[0])
            Cdate.append(Full[1])
            Cscore.append(Full[2])
            Ccomment.append(Full[3])
            Cgame.append("Halo MCC")
        else:
            continue
i = 1
num_pages = 4
for i in range(1,num_pages+1):
    driver.get("https://www.metacritic.com/game/xbox-one/halo-the-master-chief-collection/user-reviews?page=" + str(i-1))
    name_date_score = driver.find_elements_by_class_name('review_section')
    for a in name_date_score[0:-6]:
        Full = a.text.split("\n")
        if len(Full) > 2:
            Uauthor.append(Full[0])
            Udate.append(Full[1])
            Uscore.append(Full[2])
            Ucomment.append(Full[3])
            Ugame.append("Halo MCC")
        else:
            continue

# %%
# Borderlands 2 (PC)
driver.get("https://www.metacritic.com/game/pc/borderlands-2/critic-reviews")
critics = driver.find_elements_by_class_name('review_section')

for a in critics:
        Full = a.text.split("\n")
        if len(Full) > 3:
            Cauthor.append(Full[0])
            Cdate.append(Full[1])
            Cscore.append(Full[2])
            Ccomment.append(Full[3])
            Cgame.append("Borderlands 2")
        else:
            continue
i = 1
num_pages = 6
for i in range(1,num_pages+1):
    driver.get("https://www.metacritic.com/game/pc/borderlands-2/user-reviews?page=" + str(i-1))
    name_date_score = driver.find_elements_by_class_name('review_section')
    for a in name_date_score[0:-6]:
        Full = a.text.split("\n")
        if len(Full) > 3:
            Uauthor.append(Full[0])
            Udate.append(Full[1])
            Uscore.append(Full[2])
            Ucomment.append(Full[3])
            Ugame.append("Borderlands 2")
        else:
            continue

# %%
#Saints Row 4 (PC)
driver.get("https://www.metacritic.com/game/pc/saints-row-iv/critic-reviews")
critics = driver.find_elements_by_class_name('review_section')

for a in critics:
        Full = a.text.split("\n")
        if len(Full) > 3:
            Cauthor.append(Full[0])
            Cdate.append(Full[1])
            Cscore.append(Full[2])
            Ccomment.append(Full[3])
            Cgame.append("Saints Row 4")
        else:
            continue
i = 1
num_pages = 4
for i in range(1,num_pages+1):
    driver.get("https://www.metacritic.com/game/pc/saints-row-iv/user-reviews?page=" + str(i-1))
    name_date_score = driver.find_elements_by_class_name('review_section')
    for a in name_date_score[0:-6]:
        Full = a.text.split("\n")
        if len(Full) > 3:
            Uauthor.append(Full[0])
            Udate.append(Full[1])
            Uscore.append(Full[2])
            Ucomment.append(Full[3])
            Ugame.append("Saints Row 4")
        else:
            continue

# %%
#The division (PC)
driver.get("https://www.metacritic.com/game/pc/tom-clancys-the-division/critic-reviews")
critics = driver.find_elements_by_class_name('review_section')

for a in critics:
        Full = a.text.split("\n")
        if len(Full) > 3:
            Cauthor.append(Full[0])
            Cdate.append(Full[1])
            Cscore.append(Full[2])
            Ccomment.append(Full[3])
            Cgame.append("The division")
        else:
            continue
i = 1
num_pages = 4
for i in range(1,num_pages+1):
    driver.get("https://www.metacritic.com/game/pc/tom-clancys-the-division/user-reviews?page=" + str(i-1))
    name_date_score = driver.find_elements_by_class_name('review_section')
    for a in name_date_score[0:-6]:
        Full = a.text.split("\n")
        if len(Full) > 3:
            Uauthor.append(Full[0])
            Udate.append(Full[1])
            Uscore.append(Full[2])
            Ucomment.append(Full[3])
            Ugame.append("The division")
        else:
            continue

# %%
#Shadow of War (PC)
driver.get("https://www.metacritic.com/game/pc/middle-earth-shadow-of-war/critic-reviews")
critics = driver.find_elements_by_class_name('review_section')

for a in critics:
        Full = a.text.split("\n")
        if len(Full) > 3:
            Cauthor.append(Full[0])
            Cdate.append(Full[1])
            Cscore.append(Full[2])
            Ccomment.append(Full[3])
            Cgame.append("Shadow of War")
        else:
            continue
i = 1
num_pages = 3
for i in range(1,num_pages+1):
    driver.get("https://www.metacritic.com/game/pc/middle-earth-shadow-of-war/user-reviews?page=" + str(i-1))
    name_date_score = driver.find_elements_by_class_name('review_section')
    for a in name_date_score[0:-6]:
        Full = a.text.split("\n")
        if len(Full) > 3:
            Uauthor.append(Full[0])
            Udate.append(Full[1])
            Uscore.append(Full[2])
            Ucomment.append(Full[3])
            Ugame.append("Shadow of War")
        else:
            continue

# %%
#Dead Rising 4 (PC)
driver.get("https://www.metacritic.com/game/pc/dead-rising-4/critic-reviews")
critics = driver.find_elements_by_class_name('review_section')

for a in critics:
        Full = a.text.split("\n")
        if len(Full) > 3:
            Cauthor.append(Full[0])
            Cdate.append(Full[1])
            Cscore.append(Full[2])
            Ccomment.append(Full[3])
            Cgame.append("Dead Rising 4")
        else:
            continue
i = 1
num_pages = 1
for i in range(1,num_pages+1):
    driver.get("https://www.metacritic.com/game/pc/dead-rising-4/user-reviews?page=" + str(i-1))
    name_date_score = driver.find_elements_by_class_name('review_section')
    for a in name_date_score[0:-6]:
        Full = a.text.split("\n")
        if len(Full) > 3:
            Uauthor.append(Full[0])
            Udate.append(Full[1])
            Uscore.append(Full[2])
            Ucomment.append(Full[3])
            Ugame.append("Dead Rising 4")
        else:
            continue

# %%
#Cuphead (PC)
driver.get("https://www.metacritic.com/game/pc/cuphead/critic-reviews")
critics = driver.find_elements_by_class_name('review_section')

for a in critics:
        Full = a.text.split("\n")
        if len(Full) > 3:
            Cauthor.append(Full[0])
            Cdate.append(Full[1])
            Cscore.append(Full[2])
            Ccomment.append(Full[3])
            Cgame.append("Cuphead")
        else:
            continue
i = 1
num_pages = 2
for i in range(1,num_pages+1):
    driver.get("https://www.metacritic.com/game/pc/cuphead/user-reviews?page=" + str(i-1))
    name_date_score = driver.find_elements_by_class_name('review_section')
    for a in name_date_score[0:-6]:
        Full = a.text.split("\n")
        if len(Full) > 3:
            Uauthor.append(Full[0])
            Udate.append(Full[1])
            Uscore.append(Full[2])
            Ucomment.append(Full[3])
            Ugame.append("Cuphead")
        else:
            continue

# %%
#Overcooked (PC)
driver.get("https://www.metacritic.com/game/pc/overcooked!/critic-reviews")
critics = driver.find_elements_by_class_name('review_section')

for a in critics:
        Full = a.text.split("\n")
        if len(Full) > 3:
            Cauthor.append(Full[0])
            Cdate.append(Full[1])
            Cscore.append(Full[2])
            Ccomment.append(Full[3])
            Cgame.append("Overcooked")
        else:
            continue
i = 1
num_pages = 1
for i in range(1,num_pages+1):
    driver.get("https://www.metacritic.com/game/pc/overcooked!/user-reviews?page=" + str(i-1))
    name_date_score = driver.find_elements_by_class_name('review_section')
    for a in name_date_score[0:-6]:
        Full = a.text.split("\n")
        if len(Full) > 3:
            Uauthor.append(Full[0])
            Udate.append(Full[1])
            Uscore.append(Full[2])
            Ucomment.append(Full[3])
            Ugame.append("Overcooked")
        else:
            continue

# %%
#Papers Please (PC)
driver.get("https://www.metacritic.com/game/pc/papers-please/critic-reviews")
critics = driver.find_elements_by_class_name('review_section')

for a in critics:
        Full = a.text.split("\n")
        if len(Full) > 3:
            Cauthor.append(Full[0])
            Cdate.append(Full[1])
            Cscore.append(Full[2])
            Ccomment.append(Full[3])
            Cgame.append("Papers Please")
        else:
            continue
i = 1
num_pages = 3
for i in range(1,num_pages+1):
    driver.get("https://www.metacritic.com/game/pc/papers-please/user-reviews?page=" + str(i-1))
    name_date_score = driver.find_elements_by_class_name('review_section')
    for a in name_date_score[0:-6]:
        Full = a.text.split("\n")
        if len(Full) > 3:
            Uauthor.append(Full[0])
            Udate.append(Full[1])
            Uscore.append(Full[2])
            Ucomment.append(Full[3])
            Ugame.append("Papers Please")
        else:
            continue

# %%
#Sunset Overdrive (PC)
driver.get("https://www.metacritic.com/game/xbox-one/sunset-overdrive/critic-reviews")
critics = driver.find_elements_by_class_name('review_section')

for a in critics:
        Full = a.text.split("\n")
        if len(Full) > 3:
            Cauthor.append(Full[0])
            Cdate.append(Full[1])
            Cscore.append(Full[2])
            Ccomment.append(Full[3])
            Cgame.append("Sunset Overdrive")
        else:
            continue
i = 1
num_pages = 4
for i in range(1,num_pages+1):
    driver.get("https://www.metacritic.com/game/xbox-one/sunset-overdrive/user-reviews?page=" + str(i-1))
    name_date_score = driver.find_elements_by_class_name('review_section')
    for a in name_date_score[0:-6]:
        Full = a.text.split("\n")
        if len(Full) > 3:
            Uauthor.append(Full[0])
            Udate.append(Full[1])
            Uscore.append(Full[2])
            Ucomment.append(Full[3])
            Ugame.append("Sunset Overdrive")
        else:
            continue

# %%
#Nhl 18 (PC)
driver.get("https://www.metacritic.com/game/xbox-one/nhl-18/critic-reviews")
critics = driver.find_elements_by_class_name('review_section')

for a in critics:
        Full = a.text.split("\n")
        if len(Full) > 3:
            Cauthor.append(Full[0])
            Cdate.append(Full[1])
            Cscore.append(Full[2])
            Ccomment.append(Full[3])
            Cgame.append("NHL 18")
        else:
            continue
i = 1
num_pages = 1
for i in range(1,num_pages+1):
    driver.get("https://www.metacritic.com/game/xbox-one/nhl-18/user-reviews?page=" + str(i-1))
    name_date_score = driver.find_elements_by_class_name('review_section')
    for a in name_date_score[0:-6]:
        Full = a.text.split("\n")
        if len(Full) > 3:
            Uauthor.append(Full[0])
            Udate.append(Full[1])
            Uscore.append(Full[2])
            Ucomment.append(Full[3])
            Ugame.append("NHL 18")
        else:
            continue

# %%
#Quantam Break (PC)
driver.get("https://www.metacritic.com/game/xbox-one/quantum-break/critic-reviews")
critics = driver.find_elements_by_class_name('review_section')

for a in critics:
        Full = a.text.split("\n")
        if len(Full) > 3:
            Cauthor.append(Full[0])
            Cdate.append(Full[1])
            Cscore.append(Full[2])
            Ccomment.append(Full[3])
            Cgame.append("Quantum Break")
        else:
            continue
i = 1
num_pages = 4
for i in range(1,num_pages+1):
    driver.get("https://www.metacritic.com/game/xbox-one/quantum-break/user-reviews?page=" + str(i-1))
    name_date_score = driver.find_elements_by_class_name('review_section')
    for a in name_date_score[0:-6]:
        Full = a.text.split("\n")
        if len(Full) > 3:
            Uauthor.append(Full[0])
            Udate.append(Full[1])
            Uscore.append(Full[2])
            Ucomment.append(Full[3])
            Ugame.append("Quantum Break")
        else:
            continue

# %%
#Dead Island Riptide (PC)
driver.get("https://www.metacritic.com/game/pc/dead-island-riptide/critic-reviews")
critics = driver.find_elements_by_class_name('review_section')

for a in critics:
        Full = a.text.split("\n")
        if len(Full) > 3:
            Cauthor.append(Full[0])
            Cdate.append(Full[1])
            Cscore.append(Full[2])
            Ccomment.append(Full[3])
            Cgame.append("Dead Island Riptide")
        else:
            continue
i = 1
num_pages = 2
for i in range(1,num_pages+1):
    driver.get("https://www.metacritic.com/game/pc/dead-island-riptide/user-reviews?page=" + str(i-1))
    name_date_score = driver.find_elements_by_class_name('review_section')
    for a in name_date_score[0:-6]:
        Full = a.text.split("\n")
        if len(Full) > 3:
            Uauthor.append(Full[0])
            Udate.append(Full[1])
            Uscore.append(Full[2])
            Ucomment.append(Full[3])
            Ugame.append("Dead Island Riptide")
        else:
            continue

# %%
#Bioshock Inf (PC)
driver.get("https://www.metacritic.com/game/pc/bioshock-infinite/critic-reviews")
critics = driver.find_elements_by_class_name('review_section')

for a in critics:
        Full = a.text.split("\n")
        if len(Full) > 3:
            Cauthor.append(Full[0])
            Cdate.append(Full[1])
            Cscore.append(Full[2])
            Ccomment.append(Full[3])
            Cgame.append("Bioshock")
        else:
            continue
i = 1
num_pages = 16
for i in range(1,num_pages+1):
    driver.get("https://www.metacritic.com/game/pc/bioshock-infinite/user-reviews?page=" + str(i-1))
    name_date_score = driver.find_elements_by_class_name('review_section')
    for a in name_date_score[0:-6]:
        Full = a.text.split("\n")
        if len(Full) > 3:
            Uauthor.append(Full[0])
            Udate.append(Full[1])
            Uscore.append(Full[2])
            Ucomment.append(Full[3])
            Ugame.append("Bioshock")
        else:
            continue
# Out:
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# <ipython-input-16-34c55c398d94> in <module>()
#      16 num_pages = 16
#      17 for i in range(1,num_pages+1):
# ---> 18     driver.get("https://www.metacritic.com/game/pc/bioshock-infinite/user-reviews?page=" + str(i-1))
#      19     name_date_score = driver.find_elements_by_class_name('review_section')
#      20     for a in name_date_score[0:-6]:
#
# /anaconda2/envs/python3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in get(self, url)
#     330         Loads a web page in the current browser session.
#     331         """
# --> 332         self.execute(Command.GET, {'url': url})
#     333
#     334     @property
#
# /anaconda2/envs/python3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     318         response = self.command_executor.execute(driver_command, params)
#     319         if response:
# --> 320             self.error_handler.check_response(response)
#     321             response['value'] = self._unwrap_value(
#     322                 response.get('value', None))
#
# /anaconda2/envs/python3/lib/python3.6/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# TimeoutException: Message: timeout
#   (Session info: chrome=69.0.3497.100)
#   (Driver info: chromedriver=2.42.591059 (a3d9684d10d61aa0c45f6723b327283be1ebaad8),platform=Mac OS X 10.12.2 x86_64)

# %%
with open('Critics.csv', 'w') as csvfile:
    writer = csv.writer(csvfile, delimiter=',')
    a = 0
    while a < len(Cdate):
        writer.writerow([Cauthor[a],Cscore[a],Cdate[a],Ccomment[a].replace('\\',""),Cgame[a]])
        a += 1

# %%
with open('Users.csv', 'w') as csvfile:
    writer = csv.writer(csvfile, delimiter=',')
    a = 0
    while a < len(Udate):
        writer.writerow([Uauthor[a],Uscore[a],Udate[a],Ucomment[a].replace('\\',""),Ugame[a]])
        a += 1
